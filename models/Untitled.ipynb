# %%
import train_classifier_new
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/orengutman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/orengutman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/orengutman/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
mod = train_classifier_new.main()
# Out:
# Loading data...
#     DATABASE: -f
# Building model...
# Training model...
# Evaluating model...
# For category "related" this is the results:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      4766
#            1       0.86      0.55      0.67       440
#
#     accuracy                           0.95      5206
#    macro avg       0.91      0.77      0.82      5206
# weighted avg       0.95      0.95      0.95      5206
#
# --------------------------
# For category "request" this is the results:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4687
#            1       0.85      0.51      0.64       519
#
#     accuracy                           0.94      5206
#    macro avg       0.90      0.75      0.80      5206
# weighted avg       0.94      0.94      0.94      5206
#
# --------------------------
# For category "offer" this is the results:
# ...
